# %%
import pandas as pd

# %%
df = pd.read_csv('Employees.csv')

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
df.head()
# Out:
#    satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0               0.38            0.53                 2              157
# 1               0.80            0.86                 5              262
# 2               0.11            0.88                 7              272
# 3               0.37            0.52                 2              159
# 4               0.41            0.50                 2              153
#
#    timeSpent.company  workAccident  left  promotionInLast5years   dept  salary
# 0                  3             0     1                      0  sales     low
# 1                  6             0     1                      0  sales  medium
# 2                  4             0     1                      0  sales  medium
# 3                  3             0     1                      0  sales     low
# 4                  3             0     1                      0  sales     low

# %%
df.tail()
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 14994               0.11            0.85                 7              275
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
#        timeSpent.company  workAccident  left  promotionInLast5years  \
# 14994                  4             0     1                      0
# 14995                  2             0     0                      0
# 14996                  4             0     0                      0
# 14997                  5             0     0                      0
# 14998                  3             0     0                      0
#
#             dept  salary
# 14994    support  medium
# 14995      sales     low
# ...

# %%
# Data Preprocessing
# Null/Missing values
df.isnull().sum() # To get number of missing values in and every column
# Out:
# satisfactoryLevel        0
# lastEvaluation           0
# numberOfProjects         0
# avgMonthlyHours          0
# timeSpent.company        0
# workAccident             0
# left                     0
# promotionInLast5years    0
# dept                     0
# salary                   0
# dtype: int64

# %%
# If there was any missing value present in the dataset -->
# df.dropna()

# %%
# Duplicated records/rows
df[df.duplicated()]
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 263                 0.46            0.57                 2              139
# 877                 0.37            0.51                 2              127
# 974                 0.42            0.53                 2              142
# 1017                0.40            0.50                 2              127
# 1241                0.10            0.85                 6              266
# ...                  ...             ...               ...              ...
# 14985               0.95            0.84                 3              270
# 14987               0.37            0.45                 2              126
# 14988               0.43            0.57                 2              157
# 14993               0.61            0.89                 3              242
# 14994               0.11            0.85                 7              275
#
# ...

# %%
# Removing the duplicated records -->
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (11991, 10)

# %%
# Correlation Matrix --> How two columns are related to each other
# Positive correlation --> When two columns are directly proprtional
# Negative Correlation -- > When two columns are inversely proportional
# Zero Correlation --> The columns are not related with each other.
# -1 to +1 (0.98,0.67, 0.000008)

# %%
# To check the correlation matrix--
df.corr()
# Out:
#                        satisfactoryLevel  lastEvaluation  numberOfProjects  \
# satisfactoryLevel               1.000000        0.095186         -0.133246
# lastEvaluation                  0.095186        1.000000          0.270256
# numberOfProjects               -0.133246        0.270256          1.000000
# avgMonthlyHours                -0.006252        0.264678          0.331516
# timeSpent.company              -0.152915        0.096829          0.188837
# workAccident                    0.039940       -0.005695         -0.005612
# left                           -0.350558        0.013520          0.030928
# promotionInLast5years           0.019789       -0.007206         -0.000544
#
#                        avgMonthlyHours  timeSpent.company  workAccident  \
# satisfactoryLevel            -0.006252          -0.152915      0.039940
# lastEvaluation                0.264678           0.096829     -0.005695
# numberOfProjects              0.331516           0.188837     -0.005612
# ...

# %%
# Data Visualisation
# Analysing different features

# %%
df
# Out:
#        satisfactoryLevel  lastEvaluation  numberOfProjects  avgMonthlyHours  \
# 0                   0.38            0.53                 2              157
# 1                   0.80            0.86                 5              262
# 2                   0.11            0.88                 7              272
# 3                   0.37            0.52                 2              159
# 4                   0.41            0.50                 2              153
# ...                  ...             ...               ...              ...
# 14992               0.30            0.88                 5              245
# 14995               0.99            0.83                 4              274
# 14996               0.72            0.72                 4              175
# 14997               0.24            0.91                 5              177
# 14998               0.77            0.83                 6              271
#
# ...

# %%
a = ['dept','numberOfProjects','timeSpent.company','workAccident','promotionInLast5years','salary']

# %%
a
# Out:
# ['dept',
#  'numberOfProjects',
#  'timeSpent.company',
#  'workAccident',
#  'promotionInLast5years',
#  'salary']

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig = plt.subplots(figsize = (20,35)) # I want to plot multiple plots all at once.
for i,j in enumerate(a):
# The enumerate() helps out in extracting the data along with its index value
# i --> index value   j --> data present at that particular index value
    plt.subplot(3,2,i+1)  # (3,2,1) (3,2,2) (3,3,3) .... (3,3,6)
    plt.subplots_adjust(hspace = 1.0,wspace = 0.2)
    sns.countplot(x = j, data = df, hue = 'left') # hue --> for categorical data
    plt.xticks(rotation=90)
plt.show()

# %%
fig = plt.subplots(figsize = 20,25)
plt.subplot(3,2,1)
sns.countplot(x = 'dept', data = df, hue = 'left')

plt.subplot(3,2,2)
sns.countplot(x = 'number', data = df, hue = 'left')

# %% [markdown]
# # Conclusions --
# # Dept --> Most of the employees that are leaving are from sales, technical and support departments
# # No. of projects --> When it is lowest/when it is highest, the employees want to leave.
# # The safest number of projects is 3
# # Time spent --> 3 to 5 years is the most crucial time for the company.
# # Work Accident --> This doesnot effect the employees' decision for leaving the company.
# # Promotion --> All the employees who are leaving, haven't got promoted in last 5 years.
# # Salary -->  Employees who are leaving are not happy with the salary that are getting.
# #             They feel like getting underpaid.
